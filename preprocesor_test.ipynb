# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

from models import *
from preprocesor import *
import pandas as pd
from ann import load_dataset
import matplotlib.pyplot as plt

dataset = load_dataset('bitcoin.csv', resample='8H')
xt = dataset.xtest_mean
yt = dataset.ytest_mean

fig, ax = plt.subplots(1)
fig.autofmt_xdate()

plt.plot(xt, label='x');
plt.plot(yt,label='y');
plt.legend();

# %%
df = pd.DataFrame()
df['x'] = xt
df['y'] = yt
df
# Out:
#                                 x             y
# Timestamp
# 2018-02-11 16:00:00  5.437177e+06  5.252158e+06
# 2018-02-12 00:00:00  5.290275e+06  5.187600e+06
# 2018-02-12 08:00:00  5.175845e+06  5.370842e+06
# 2018-02-12 16:00:00  5.235448e+06  5.451664e+06
# 2018-02-13 00:00:00  5.252158e+06  5.464034e+06
# 2018-02-13 08:00:00  5.187600e+06  5.370668e+06
# 2018-02-13 16:00:00  5.370842e+06  5.330984e+06
# 2018-02-14 00:00:00  5.451664e+06  5.343280e+06
# 2018-02-14 08:00:00  5.464034e+06  5.604956e+06
# 2018-02-14 16:00:00  5.370668e+06  5.720712e+06
# 2018-02-15 00:00:00  5.330984e+06  5.858071e+06
# 2018-02-15 08:00:00  5.343280e+06  5.926687e+06
# 2018-02-15 16:00:00  5.604956e+06  6.195391e+06
# 2018-02-16 00:00:00  5.720712e+06  6.333295e+06
# 2018-02-16 08:00:00  5.858071e+06  6.266529e+06
# 2018-02-16 16:00:00  5.926687e+06  6.268977e+06
# 2018-02-17 00:00:00  6.195391e+06  6.410845e+06
# 2018-02-17 08:00:00  6.333295e+06  6.531770e+06
